# %% [markdown]
# <a href="https://colab.research.google.com/github/jeffersonsps61/dio-desafio-github-primeiro-repositorio/blob/main/An%C3%A1lise_de_dados_com_Python_e_Pandas_DIO_UNIMED_BH.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
adventure = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/Curso Python Pandas Digital Innovation master/datasets/AdventureWorks.xlsx')
adventure.head()
# Out:
#   Data Venda Data Envio  ID Loja  ID Produto  ID Cliente       No. Venda  \
# 0 2008-05-09 2008-05-29      199         384       18839  200805093CS607
# 1 2008-05-12 2008-05-17      306         384       19051  200805123CS567
# 2 2008-05-14 2008-05-20      306         384       19052  200805143CS576
# 3 2008-05-21 2008-05-27      306         384       19052  200805213CS576
# 4 2008-06-20 2008-06-27      306         384       19053  200806203CS586
#
#    Custo Unitário  Preço Unitário  Quantidade  Valor Desconto  Valor Venda  \
# 0          348.58           758.0           6             0.0       4548.0
# 1          348.58           758.0           6             0.0       4548.0
# 2          348.58           758.0           6             0.0       4548.0
# 3          348.58           758.0           6             0.0       4548.0
# 4          348.58           758.0           6             0.0       4548.0
#
# ...

# %%
adventure.columns
# Out:
# Index(['Data Venda', 'Data Envio', 'ID Loja', 'ID Produto', 'ID Cliente',
#        'No. Venda', 'Custo Unitário', 'Preço Unitário', 'Quantidade',
#        'Valor Desconto', 'Valor Venda', 'Produto', 'Fabricante', 'Marca',
#        'Classe', 'Cor'],
#       dtype='object')

# %%
adventure.shape
# Out:
# (904, 16)

# %%
adventure.dtypes
# Out:
# Data Venda        datetime64[ns]
# Data Envio        datetime64[ns]
# ID Loja                    int64
# ID Produto                 int64
# ID Cliente                 int64
# No. Venda                 object
# Custo Unitário           float64
# Preço Unitário           float64
# Quantidade                 int64
# Valor Desconto           float64
# Valor Venda              float64
# Produto                   object
# Fabricante                object
# Marca                     object
# Classe                    object
# Cor                       object
# dtype: object

# %%
adventure.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 904 entries, 0 to 903
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Data Venda      904 non-null    datetime64[ns]
#  1   Data Envio      904 non-null    datetime64[ns]
#  2   ID Loja         904 non-null    int64
#  3   ID Produto      904 non-null    int64
#  4   ID Cliente      904 non-null    int64
#  5   No. Venda       904 non-null    object
#  6   Custo Unitário  904 non-null    float64
#  7   Preço Unitário  904 non-null    float64
#  8   Quantidade      904 non-null    int64
#  9   Valor Desconto  904 non-null    float64
#  10  Valor Venda     904 non-null    float64
#  11  Produto         904 non-null    object
#  12  Fabricante      904 non-null    object
#  13  Marca           904 non-null    object
#  14  Classe          904 non-null    object
#  15  Cor             904 non-null    object
# ...

# %%
adventure.describe()
# Out:
#                           Data Venda                     Data Envio  \
# count                            904                            904
# mean   2009-01-01 23:42:28.672566528  2009-01-10 12:44:36.106194688
# min              2008-01-02 00:00:00            2008-01-12 00:00:00
# 25%              2008-07-04 18:00:00            2008-07-11 18:00:00
# 50%              2008-12-24 00:00:00            2008-12-29 12:00:00
# 75%              2009-06-22 06:00:00            2009-07-03 06:00:00
# max              2009-12-31 00:00:00            2010-01-12 00:00:00
# std                              NaN                            NaN
#
#           ID Loja   ID Produto    ID Cliente  Custo Unitário  Preço Unitário  \
# count  904.000000   904.000000    904.000000      904.000000      904.000000
# mean   270.015487  1225.238938  19029.092920      272.006150      742.527965
# min    199.000000   366.000000  18815.000000        5.090000        9.990000
# ...

# %%
matriz_corelacao = adventure.corr(numeric_only=True)

# %%
#mask = np.triu(np.ones_like(matriz_correlacao, dtype=bool))
mask = np.triu(np.ones_like(matriz_corelacao, dtype = bool),k=1)
sns.heatmap(adventure.corr(numeric_only=True), cmap='nipy_spectral_r', annot=True, mask=mask)
# Out:
# <Axes: >

# %%
sns.pairplot(data = adventure,
             diag_kind="kde",
             kind="scatter",
             palette="Colorblind",
             corner=True)
# Out:
# /usr/local/lib/python3.12/dist-packages/seaborn/axisgrid.py:1513: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# /usr/local/lib/python3.12/dist-packages/seaborn/axisgrid.py:1513: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# /usr/local/lib/python3.12/dist-packages/seaborn/axisgrid.py:1513: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# /usr/local/lib/python3.12/dist-packages/seaborn/axisgrid.py:1513: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# /usr/local/lib/python3.12/dist-packages/seaborn/axisgrid.py:1513: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# ...

# %%
# Qual foi a receita total
print('Receital total= ', round(adventure['Valor Venda'].sum(),2))
# Out:
# Receital total=  5984606.14

# %%
adventure.groupby('Produto')['Valor Venda'].sum().sort_values(ascending=False)
# Out:
# Produto
# Fabrikam Trendsetter 2/3'' 17mm X100 Grey          961037.0000
# Fabrikam Trendsetter 2/3'' 17mm X100 Black         821396.8000
# Fabrikam Trendsetter 1/3'' 8.5mm X200 Black        799809.3900
# Fabrikam Trendsetter 1/3'' 8.5mm X200 Grey         781334.2000
# Adventure Works Laptop15.4W M1548 Black            746789.1800
# Fabrikam Trendsetter 1/3'' 8.5mm X200 White        714029.0800
# Adventure Works Laptop15.4W M1548 Red              709813.9400
# Headphone Adapter for Contoso Phone E130 Silver    226591.3818
# Headphone Adapter for Contoso Phone E130 White     223805.1708
# Name: Valor Venda, dtype: float64

# %%
plt.figure(figsize=(6,3))
sns.barplot(x='Produto',
            y='Valor Venda',
            order=adventure.groupby('Produto')['Valor Venda'].sum().sort_values(ascending=False).index,
            errorbar=None,
            estimator='sum', # <--- CORREÇÃO: Plota a SOMA total na altura da barra
            data=adventure)
plt.xticks(rotation=45, ha='right') # Rotaciona rótulos para melhor leitura
plt.ticklabel_format(style='plain', axis='y') # Evita notação científica no eixo Y (se necessário)
sns.despine()
plt.show()

# %%
# Qual o custo total?

adventure['Custo Total'] = adventure['Custo Unitário']*adventure['Quantidade']
print('Custo Total=',round(adventure['Custo Total'].sum(),2))
# Out:
# Custo Total= 2486783.05

# %%
adventure['lucro'] = adventure['Valor Venda'] - adventure['Custo Total']
print('Lucro Total=',round(adventure['lucro'].sum(),2))
# Out:
# Lucro Total= 3497823.09

# %%
adventure.groupby('Fabricante')['lucro'].sum().sort_values(ascending=False)
# Out:
# Fabricante
# Fabrikam, Inc.     2.591112e+06
# Adventure Works    7.120362e+05
# Contoso, Ltd       1.946750e+05
# Name: lucro, dtype: float64

# %%
fig, ax = plt.subplots(1,2,figsize=(10,4))

sns.barplot(x='Fabricante',
            y='lucro',
            order=adventure.groupby('Fabricante')['lucro'].sum().sort_values(ascending=False).index,
            errorbar=None,
            estimator='sum', # <--- CORREÇÃO: Plota a SOMA total na altura da barra
            data=adventure,
            color='red',
            ax=ax[0])

ax[0].set(title='Lucro por Fabricante',
          xlabel='Fabricante',
          ylabel='Lucro') # Rotaciona rótulos para melhor leitura
#ax[0].tick_params(axis='x', rotation=45)
ax[0].ticklabel_format(style='plain', axis='y') # Evita notação científica no eixo Y (se necessário)

sns.boxplot(x='Fabricante',
            y='lucro',
            data=adventure,
            color='purple',
            ax=ax[1])

ax[1].set(title='Distribuição dos lucros',
          xlabel='Fabricante',
          ylabel='Lucro')

sns.despine()
plt.tight_layout()
plt.show()

# %%
adventure['Tempo de Envio'] = (adventure['Data Envio'] - adventure['Data Venda']).dt.days

# %%
adventure.columns
# Out:
# Index(['Data Venda', 'Data Envio', 'ID Loja', 'ID Produto', 'ID Cliente',
#        'No. Venda', 'Custo Unitário', 'Preço Unitário', 'Quantidade',
#        'Valor Desconto', 'Valor Venda', 'Produto', 'Fabricante', 'Marca',
#        'Classe', 'Cor', 'Custo Total', 'lucro', 'Tempo de Envio'],
#       dtype='object')
